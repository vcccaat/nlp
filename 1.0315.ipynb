# %%
from collections import Counter
from itertools import combinations
from math import sqrt
import random
from keras.layers import Concatenate, Dense, Dot, Dropout, Embedding, Input, Reshape, LeakyReLU, Add
from keras.models import Model
from keras.callbacks import Callback, ModelCheckpoint
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import tensorflow


STUDENT_ID = '23846183'

random.seed(2019)
np.random.seed(2019)
tensorflow.set_random_seed(2019)


# Function to calculate RMSE
def rmse(pred, actual):
    # Ignore nonzero terms.
    pred = pred[actual.nonzero()].flatten()
    actual = actual[actual.nonzero()].flatten()
    return sqrt(mean_squared_error(pred, actual))


def build_deepwide_model(len_continuous, deep_vocab_lens, len_wide, embed_size):
    input_list = []
    continuous_input = Input(shape=(len_continuous,), dtype='float32', name='continuous_input')
    input_list.append(continuous_input)

    emb_list = []
    for vocab_size in deep_vocab_lens:
        _input = Input(shape=(1,), dtype='int32')
        input_list.append(_input)
        _emb = Embedding(output_dim=embed_size, input_dim=vocab_size, input_length=1)(_input)
        _emb = Reshape((embed_size,))(_emb)
        emb_list.append(_emb)
    
    wide_input = Input(shape=(len_wide,), dtype='float32')
    input_list.append(wide_input)
    
    deep_input = Concatenate()(emb_list + [continuous_input])
    
    
    dense_1 = Dense(256, activation='linear')(deep_input)
    dense_1 = LeakyReLU(alpha=0.001)(dense_1)
    #dense_1_dp = Dropout(0.01)(dense_1)
    
    dense_2 = Dense(128, activation='linear')(dense_1)
    dense_2 = Concatenate()([dense_2, dense_1])
    dense_2 = LeakyReLU(alpha=0.001)(dense_2)
    
    #dense_2_dp = Dropout(0.01)(dense_2)
    dense_3 = Dense(64, activation='linear')(dense_2)
    #dense_3_dp = Dropout(0.01)(dense_3)
    dense_2 = Concatenate()([dense_3, dense_2, dense_1])
    dense_3_dp = LeakyReLU(alpha=0.001)(dense_3)

    
    fc_input = Concatenate()([dense_1, dense_2, dense_3_dp, wide_input])
    
    fc_input = LeakyReLU(alpha=0.001)(fc_input)
    model_output = Dense(1)(fc_input)
    model = Model(inputs=input_list,
                  outputs=model_output)
    return model


def get_continuous_features(df, continuous_columns):
    continuous_features = df[continuous_columns].values
    return continuous_features


def get_top_k_p_combinations(df, comb_p, topk, output_freq=False):
    def get_category_combinations(categories_str, comb_p=2):
        categories = categories_str.split(', ')
        return list(combinations(categories, comb_p))
    all_categories_p_combos = df["item_categories"].apply(
        lambda x: get_category_combinations(x, comb_p)).values.tolist()
    all_categories_p_combos = [tuple(t) for item in all_categories_p_combos for t in item]
    tmp = dict(Counter(all_categories_p_combos))
    sorted_categories_combinations = list(sorted(tmp.items(), key=lambda x: x[1], reverse=True))
    if output_freq:
        return sorted_categories_combinations[:topk]
    else:
        return [t[0] for t in sorted_categories_combinations[:topk]]


def get_wide_features(df):
    def categories_to_binary_output(categories):
        binary_output = [0 for _ in range(len(selected_categories_to_idx))]
        for category in categories.split(', '):
            if category in selected_categories_to_idx:
                binary_output[selected_categories_to_idx[category]] = 1
            else:
                binary_output[0] = 1
        return binary_output
    def categories_cross_transformation(categories):
        current_category_set = set(categories.split(', '))
        corss_transform_output = [0 for _ in range(len(top_combinations))]
        for k, comb_k in enumerate(top_combinations):
            if len(current_category_set & comb_k) == len(comb_k):
                corss_transform_output[k] = 1
            else:
                corss_transform_output[k] = 0
        return corss_transform_output

    category_binary_features = np.array(df.item_categories.apply(
        lambda x: categories_to_binary_output(x)).values.tolist())
    category_corss_transform_features = np.array(df.item_categories.apply(
        lambda x: categories_cross_transformation(x)).values.tolist())
    return np.concatenate((category_binary_features, category_corss_transform_features), axis=1)


if __name__ == "__main__":
    tr_df = pd.read_csv("data/train.csv")
    val_df = pd.read_csv("data/valid.csv")
    te_df = pd.read_csv("data/test.csv")

    tr_ratings = tr_df.stars.values
    val_ratings = val_df.stars.values

    user_df = pd.read_json("data/user.json")
    item_df = pd.read_json("data/business.json")
    user_df = user_df.rename(index=str, columns={t: 'user_' + t for t in user_df.columns if t != 'user_id'})
    item_df = item_df.rename(index=str, columns={t: 'item_' + t for t in item_df.columns if t != 'business_id'})

    tr_df["index"] = tr_df.index
    val_df["index"]  = val_df.index
    te_df["index"] = te_df.index
    tr_df = pd.merge(pd.merge(tr_df, user_df, on='user_id'), item_df, on='business_id').sort_values(by=['index']).reset_index(drop=True)
    val_df = pd.merge(pd.merge(val_df, user_df, on='user_id'), item_df, on='business_id').sort_values(by=['index']).reset_index(drop=True)
    te_df = pd.merge(pd.merge(te_df, user_df, on='user_id'), item_df, on='business_id').sort_values(by=['index']).reset_index(drop=True)

    # Continuous features
    print("Prepare continuous features...")
    continuous_columns = ["user_average_stars",
#                           "user_cool", 
#                           "user_fans", 
                          "user_review_count", "user_useful",
#                           "user_funny",
#                           "item_is_open", "item_latitude", "item_longitude", 
                          "item_review_count", "item_stars"]

    tr_continuous_features = get_continuous_features(tr_df, continuous_columns)
    val_continuous_features = get_continuous_features(val_df, continuous_columns)
    te_continuous_features = get_continuous_features(te_df, continuous_columns)
    scaler = StandardScaler().fit(tr_continuous_features)
    tr_continuous_features = scaler.transform(tr_continuous_features)
    val_continuous_features = scaler.transform(val_continuous_features)
    te_continuous_features = scaler.transform(te_continuous_features)

    # Deep features
    print("Prepare deep features...")
    item_deep_columns = ["item_city", "item_postal_code", "item_state"]
    item_deep_vocab_lens = []
    for col_name in item_deep_columns:
        tmp = item_df[col_name].unique()
        vocab = dict(zip(tmp, range(1, len(tmp) + 1)))
        item_deep_vocab_lens.append(len(vocab) + 1)
        item_df[col_name + "_idx"] = item_df[col_name].apply(lambda x: vocab[x] if x in vocab else 0)
    item_deep_idx_columns = [t + "_idx" for t in item_deep_columns]
    item_to_deep_features = dict(zip(item_df.business_id.values, item_df[item_deep_idx_columns].values.tolist()))
    tr_deep_features = np.array(tr_df.business_id.apply(lambda x: item_to_deep_features[x]).values.tolist())
    val_deep_features = np.array(val_df.business_id.apply(lambda x: item_to_deep_features[x]).values.tolist())
    te_deep_features = np.array(te_df.business_id.apply(lambda x: item_to_deep_features[x]).values.tolist())

    # Wide (Category) features
    
    # How to use attribute column for item
    print("Prepare wide features...")
    #   Prepare binary encoding for each selected categories
    all_categories = [category for category_list in item_df.item_categories.values for category in category_list.split(", ")]
    category_sorted = sorted(Counter(all_categories).items(), key=lambda x: x[1], reverse=True)
    selected_categories = [t[0] for t in category_sorted[:900]]
    selected_categories_to_idx = dict(zip(selected_categories, range(1, len(selected_categories) + 1)))
    selected_categories_to_idx['unk'] = 0
    idx_to_selected_categories = {val: key for key, val in selected_categories_to_idx.items()}
    #   Prepare Cross transformation for each categories
    top_combinations = []
    top_combinations += get_top_k_p_combinations(tr_df, 2, 200, output_freq=False)
    top_combinations += get_top_k_p_combinations(tr_df, 3, 30, output_freq=False)
    top_combinations += get_top_k_p_combinations(tr_df, 4, 20, output_freq=False)
    top_combinations += get_top_k_p_combinations(tr_df, 5, 10, output_freq=False)
    
    top_combinations = [set(t) for t in top_combinations]

    tr_wide_features = get_wide_features(tr_df)
    val_wide_features = get_wide_features(val_df)
    te_wide_features = get_wide_features(te_df)

    # Build input
    tr_features = []
    tr_features.append(tr_continuous_features.tolist())
    tr_features += [tr_deep_features[:,i].tolist() for i in range(len(tr_deep_features[0]))]
    tr_features.append(tr_wide_features.tolist())
    val_features = []
    val_features.append(val_continuous_features.tolist())
    val_features += [val_deep_features[:,i].tolist() for i in range(len(val_deep_features[0]))]
    val_features.append(val_wide_features.tolist())
    te_features = []
    te_features.append(te_continuous_features.tolist())
    te_features += [te_deep_features[:,i].tolist() for i in range(len(te_deep_features[0]))]
    te_features.append(te_wide_features.tolist())

    # Model training
    deepwide_model = build_deepwide_model(
        len(tr_continuous_features[0]),
        item_deep_vocab_lens,  
        len(tr_wide_features[0]), 
        embed_size=100)
    deepwide_model.compile(optimizer='adagrad', loss='mse')
    history = deepwide_model.fit(
        tr_features, 
        tr_ratings, 
        epochs=1, verbose=1, callbacks=[ModelCheckpoint('model.h5')])

    # Make Prediction
    y_pred = deepwide_model.predict(tr_features)
    print("TRAIN RMSE: ", rmse(y_pred, tr_ratings))
    y_pred = deepwide_model.predict(val_features)
    print("VALID RMSE: ", rmse(y_pred, val_ratings))
#     y_pred = deepwide_model.predict(te_features)
#     res_df = pd.DataFrame()
#     res_df['pred'] = y_pred[:, 0]
#     res_df.to_csv("{}.csv".format(STUDENT_ID), index=False)
#     print("Writing test predictions to file done.")
# Out:
# Prepare continuous features...
# Prepare deep features...
# Prepare wide features...
# Epoch 1/1
# 100000/100000 [==============================] - 28s 281us/step - loss: 1.1053
# TRAIN RMSE:  1.0241602816149316
# VALID RMSE:  1.031410890952519

# %%
# total features available 
print(len(user_df.columns))
list(user_df.columns)

# selected features
# ["user_average_stars", "user_cool", "user_fans", 
#                           "user_review_count", "user_useful", "user_funny",
#                           "item_is_open", "item_latitude", "item_longitude", 
#                           "item_review_count", "item_stars"]
# Out:
# 21
# ['user_average_stars',
#  'user_compliment_cool',
#  'user_compliment_cute',
#  'user_compliment_funny',
#  'user_compliment_hot',
#  'user_compliment_list',
#  'user_compliment_more',
#  'user_compliment_note',
#  'user_compliment_photos',
#  'user_compliment_plain',
#  'user_compliment_profile',
#  'user_compliment_writer',
#  'user_cool',
#  'user_elite',
#  'user_fans',
#  'user_funny',
#  'user_name',
#  'user_review_count',
#  'user_useful',
#  'user_id',
#  'user_yelping_since']

# %%
# Out:
#       user_average_stars  user_compliment_cool  user_compliment_cute  \
# 1019                4.14                     0                     0
# 1022                3.37                     0                     0
# 1025                4.28                     0                     0
# 1027                4.16                     0                     0
# 1055                3.63                     0                     0
# 1056                3.88                     0                     0
# 1058                4.00                     0                     0
# 1063                3.93                     0                     0
# 1066                3.96                     0                     0
# 1070                4.00                     0                     0
# 1075                4.62                     0                     0
# 1076                4.00                     2                     0
# 1087                3.59                     1                     0
# 1089                3.86                     4                     0
# 1092                3.92                     0                     0
# 1094                3.38                     0                     0
# 1098                2.86                     0                     0
# 1106                4.27                     0                     0
# 1108                3.50                     0                     0
# 1117                4.26                     2                     0
# 1126                3.95                     0                     0
# 1132                3.13                     0                     0
# 1137                4.92                     0                     0
# 1146                3.98                     0                     0
# 1152                4.98                     0                     0
# 1174                4.18                     0                     0
# 1178                4.44                     3                     0
# 1185                4.24                     0                     0
# 1186                3.55                     1                     0
# 1188                3.65                     0                     0
# ...                  ...                   ...                   ...
# 822                 3.17                     0                     0
# 841                 4.02                     0                     0
# 846                 4.70                     0                     0
# 853                 3.68                     0                     0
# 858                 4.26                     0                     0
# 859                 4.13                     1                     0
# 863                 3.33                     0                     0
# 868                 3.62                     0                     0
# 869                 2.78                     0                     0
# 870                 3.59                     0                     0
# 879                 3.71                     0                     0
# 893                 4.10                     1                     0
# 898                 3.20                     1                     0
# 902                 3.67                     6                     0
# 907                 4.00                     1                     0
# 909                 2.61                     0                     0
# 911                 3.86                     0                     0
# 914                 4.54                     1                     0
# 916                 3.57                     2                     0
# 925                 3.62                     0                     0
# 926                 2.23                     0                     0
# 928                 4.28                     0                     0
# 929                 4.31                     0                     0
# 937                 3.88                     9                     3
# 947                 4.40                     0                     0
# 948                 3.60                     0                     0
# 963                 3.83                     0                     0
# 966                 4.06                     0                     0
# 978                 3.68                     0                     0
# 990                 3.43                     3                     0
#
#       user_compliment_funny  user_compliment_hot  user_compliment_list  \
# 1019                      0                    0                     0
# 1022                      0                    0                     0
# 1025                      0                    1                     0
# 1027                      0                    0                     0
# 1055                      0                    1                     0
# 1056                      0                    0                     0
# 1058                      0                    0                     0
# 1063                      0                    1                     0
# 1066                      0                    0                     0
# 1070                      0                    0                     0
# 1075                      0                    0                     0
# 1076                      2                    0                     0
# 1087                      1                    0                     0
# 1089                      4                    1                     0
# 1092                      0                    0                     0
# 1094                      0                    1                     0
# 1098                      0                    0                     0
# 1106                      0                    0                     0
# 1108                      0                    0                     0
# 1117                      2                    0                     0
# 1126                      0                    0                     0
# 1132                      0                    0                     0
# 1137                      0                    0                     0
# 1146                      0                    0                     0
# 1152                      0                    0                     0
# 1174                      0                    0                     0
# 1178                      3                    0                     0
# 1185                      0                    0                     0
# 1186                      1                    0                     0
# 1188                      0                    0                     0
# ...                     ...                  ...                   ...
# 822                       0                    0                     0
# 841                       0                    0                     0
# 846                       0                    0                     0
# 853                       0                    0                     0
# 858                       0                    0                     0
# 859                       1                    2                     0
# 863                       0                    0                     0
# 868                       0                    1                     0
# 869                       0                    0                     0
# 870                       0                    0                     0
# 879                       0                    1                     0
# 893                       1                    0                     0
# 898                       1                    0                     0
# 902                       6                    0                     0
# 907                       1                    0                     0
# 909                       0                    0                     0
# 911                       0                    0                     0
# 914                       1                    0                     0
# 916                       2                    1                     2
# 925                       0                    0                     0
# 926                       0                    0                     0
# 928                       0                    0                     0
# 929                       0                    0                     0
# 937                       9                    4                     0
# 947                       0                    0                     0
# 948                       0                    0                     0
# 963                       0                    0                     0
# 966                       0                    0                     0
# 978                       0                    0                     0
# 990                       3                    1                     0
#
#       user_compliment_more  user_compliment_note  user_compliment_photos  \
# 1019                     0                     0                       0
# 1022                     0                     2                       0
# 1025                     0                     1                       0
# 1027                     0                     1                       0
# 1055                     1                     0                       0
# 1056                     0                     0                       0
# 1058                     1                     0                       0
# 1063                     0                     2                       0
# 1066                     0                     0                       0
# 1070                     0                     0                       0
# 1075                     0                     0                       0
# 1076                     0                     0                       0
# 1087                     0                     1                       0
# 1089                     1                     2                       0
# 1092                     0                     0                       0
# 1094                     0                     0                       0
# 1098                     0                     0                       0
# 1106                     0                     0                       0
# 1108                     0                     0                       0
# 1117                     0                     0                       0
# 1126                     0                     1                       0
# 1132                     0                     1                       1
# 1137                     0                     0                       0
# 1146                     0                     1                       0
# 1152                     0                     1                       0
# 1174                     0                     0                       0
# 1178                     0                     0                       0
# 1185                     0                     1                       0
# 1186                     1                     1                       0
# 1188                     0                     0                       0
# ...                    ...                   ...                     ...
# 822                      0                     0                       0
# 841                      0                     0                       0
# 846                      0                     0                       0
# 853                      0                     0                       0
# 858                      0                     0                       0
# 859                      1                     1                       0
# 863                      0                     0                       0
# 868                      0                     0                       0
# 869                      0                     0                       0
# 870                      0                     0                       0
# 879                      0                     0                       0
# 893                      1                     0                       0
# 898                      0                     0                       0
# 902                      0                     6                       0
# 907                      1                     0                       0
# 909                      0                     0                       0
# 911                      0                     0                       0
# 914                      0                     0                       0
# 916                      1                     5                       0
# 925                      0                     0                       0
# 926                      0                     0                       0
# 928                      0                     0                       0
# 929                      0                     0                       0
# 937                      0                     8                       1
# 947                      0                     0                       0
# 948                      1                     3                       0
# 963                      0                     0                       0
# 966                      0                     0                       0
# 978                      0                     1                       0
# 990                      1                     3                       0
#
#       user_compliment_plain         ...           user_compliment_writer  \
# 1019                      0         ...                                0
# 1022                      0         ...                                0
# 1025                      1         ...                                0
# 1027                      0         ...                                0
# 1055                      3         ...                                0
# 1056                      1         ...                                0
# 1058                      0         ...                                0
# 1063                      0         ...                                1
# 1066                      2         ...                                0
# 1070                      0         ...                                0
# 1075                      2         ...                                0
# 1076                      0         ...                                0
# 1087                      1         ...                                0
# 1089                      3         ...                                1
# 1092                      1         ...                                0
# 1094                      2         ...                                0
# 1098                      0         ...                                0
# 1106                      0         ...                                0
# 1108                      2         ...                                1
# 1117                      0         ...                                0
# 1126                      0         ...                                0
# 1132                      0         ...                                0
# 1137                      0         ...                                0
# 1146                      2         ...                                0
# 1152                      2         ...                                1
# 1174                      0         ...                                0
# 1178                      1         ...                                0
# 1185                      0         ...                                0
# 1186                      1         ...                                0
# 1188                      2         ...                                0
# ...                     ...         ...                              ...
# 822                       0         ...                                1
# 841                       1         ...                                0
# 846                       0         ...                                0
# 853                       0         ...                                0
# 858                       1         ...                                0
# 859                       2         ...                                0
# 863                       0         ...                                0
# 868                       2         ...                                0
# 869                       2         ...                                0
# 870                       0         ...                                0
# 879                       0         ...                                0
# 893                       0         ...                                0
# 898                       1         ...                                0
# 902                       3         ...                                4
# 907                       2         ...                                0
# 909                       0         ...                                0
# 911                       0         ...                                0
# 914                       1         ...                                0
# 916                       0         ...                                1
# 925                       0         ...                                0
# 926                       1         ...                                0
# 928                       0         ...                                0
# 929                       0         ...                                0
# 937                       6         ...                                1
# 947                       5         ...                                2
# 948                       1         ...                                0
# 963                       0         ...                                0
# 966                       1         ...                                0
# 978                       1         ...                                2
# 990                       0         ...                                1
#
#       user_cool  user_elite user_fans  user_funny            user_name  \
# 1019          1                     0           1                Lynne
# 1022         32                     0          23              Natasha
# 1025          0                     0           8                 Elle
# 1027         17                     0          13                 Tami
# 1055         11                     0          11                Rngox
# 1056         17                     0          12                Butch
# 1058          5                     0           3              Mishell
# 1063         12                     0           8                    C
# 1066         14                     0           8                Winna
# 1070          7                     0           4                 Rilo
# 1075         14                     0           4            Charmayne
# 1076         13                     0           5               Nicole
# 1087          1                     0           4                 Elle
# 1089         31   2017,2018         0          16                 Judy
# 1092          7                     0           2              Kirstin
# 1094          6                     0           9             Brittany
# 1098          6                     0           9              Charles
# 1106          0                     0           0                 Dawn
# 1108         33                     0          12              Jasmine
# 1117          7                     0           4                Laura
# 1126          2                     0           7                 Bret
# 1132          7                     0           6                Diana
# 1137          4                     0           1                Kevin
# 1146         10                     0          10                 Ting
# 1152          4                     0           2               Bonnie
# 1174          2                     0           2            Alexander
# 1178         33                     0          42                 Bebe
# 1185         10                     0           3                  Sam
# 1186          9                     0          11                Nisha
# 1188         11                     0          18               Justin
# ...         ...         ...       ...         ...                  ...
# 822           5                     0           3                 Miss
# 841           3                     0           4              William
# 846           5                     0           0                Aaron
# 853           2                     0           3                Laura
# 858           7                     0          10              Anthony
# 859          38                     0          42                 Jake
# 863           2                     0           5                  mia
# 868          13                     0          17                Cindy
# 869           9                     0          12                  The
# 870          13                     0          17                Kelly
# 879           5                     0           2                 Jodi
# 893           5                     0           2               Warren
# 898           6                     0           1              Ronalyn
# 902          35   2015,2016         0          45               Tamara
# 907          22                     0          15                 Mike
# 909           4                     0           3               Keyuan
# 911           9        2018         0           7             Jonathan
# 914           3                     0           1                Janna
# 916          13        2017         0          19                Shari
# 925           0                     0           3              Cynthia
# 926           4                     0           2               Andria
# 928           1                     0           2               Joseph
# 929           3                     0           4                 Jeff
# 937          47                     0          25                 Lisa
# 947           5   2017,2018         0           1              Jessica
# 948          16                     0           5                Class
# 963           1                     0           2                Heidi
# 966           2                     0           4  Queen City Reviewer
# 978           8                     0           4              Claudia
# 990          59                     0          63                   JR
#
#      user_review_count  user_useful                           user_id  \
# 1019                35            8  110362ea155bc27f2faceb6dc76b4e5c
# 1022                39           56  b29e7ca89b94b87372bb7f2f619d0370
# 1025                24            7  d1799915f2d5bc12f001dcb9df103042
# 1027                30           34  fa8b8042848b2d876fb28ca6652cf22d
# 1055                96           81  4b5f6fe3906ac1270cdf81b40b6e3a0f
# 1056                32           44  b58d81735f484d67a77308b74a3722ca
# 1058                27           32  5e20ce6186496644908ea094798ff04b
# 1063                43           97  8f01755e4582caf9b2b4d55bb4b0880a
# 1066                23           36  eeff9485f8ca9445268745967b651fe5
# 1070                40           26  19691083b44502f78787d7d26bfe5701
# 1075                47           33  5b62625f8e82fb49e3985c4f3d9253b6
# 1076                23           43  5284111cce5ab239f36372af5d3e2e3b
# 1087                37           15  dbc051393570e837f96efe72d84e4ef9
# 1089                40          105  58ab97351ddd4328d9ed33cfdc13fb51
# 1092                24           10  cadec605b8efcce9ef044f2fe2e534c6
# 1094                29           24  4c13bafe97666d3a83081939cf40ea8f
# 1098                46           20  1571837c269ad54eb1c3a1bfc9e987fd
# 1106                48            5  2b2d75a6092ebe6d927201aebdc414db
# 1108                48           50  722fddaadccaaa11d2c3a063d02fb141
# 1117                97           49  11877e2ead130ff264d8819ff837a1ec
# 1126                22           11  2ad1671339b91237fce73f1696baf550
# 1132                22           44  a66076249c04dfc324a80d310a58bdbd
# 1137                37           14  30eaa45ee339a75795436e425ed027b2
# 1146                43           43  3b989be357f096af7b0e59c1a47b1a66
# 1152                36           20  aa08e4be0c786e4d5dfff6a4bc6d6b1e
# 1174                68            7  87e33b64d8b211cfdccd807a34ab3cab
# 1178                45           84  93682c2b38a370ccc25e52f5b205d57b
# 1185                20           27  8be24dced1e9697bfa7b7fc575d29549
# 1186                29           23  5083f55af5065f0b0710922893c59069
# 1188                68           52  6f5c68ad766def8949d8f2cd3c783a8c
# ...                ...          ...                               ...
# 822                 45           18  200e0e0c8a9d50f4b51daf8aab9e4f12
# 841                 44           16  411759e45c9718ae765b1911ce5f2829
# 846                 27            7  fa363cb83a378de6933814ea64d908ad
# 853                 54           28  ee22608ec3a19b3d4bd1c7cba91ef3e5
# 858                 40           15  d2bf677e2a2e9e7a7f56149267dec334
# 859                 24           73  1c30063723d908927dad14c045267b35
# 863                 23           17  4836c300980c20ba7bcd241e95971c6a
# 868                 57           49  76425f0f56225ead02d97c6abb08fc8e
# 869                 52           86  98242cfd2ee2046e944852dee7f1a3fc
# 870                 27           33  3a4c8cf44ab47542b319dcb5177032a2
# 879                 21           37  4003481bcd2ca1630c4bf01e09b06a36
# 893                 29           11  eae6265bdcaa1dfc3f10d8948711128f
# 898                 19            9  24bf93ac62e3a1b343f239af1e79d41c
# 902                 96          185  5438412a9c2ca78e5cf14c5afba5d150
# 907                 59           75  49115bc64c94214abe4908be87dadfc7
# 909                 26            9  514e59b9981e13ea0e98fbe80bc274cf
# 911                 71           31  fd8db2e08aae302f0cda0d9e58ea88d8
# 914                 21           17  e4eac02255a0932e050e22d94130baf1
# 916                 46           43  877a83cc8a7f7538cb0c1d1f6d827b16
# 925                 22           19  a61a5384fcaa157f71e10933bc681402
# 926                 31           13  655265ddb8fc5eea56676f611d61a2bb
# 928                 32            7  242156c4a6c58c28f1199d29afc31541
# 929                 24           14  3854cb72e973da6e3cd507997a906e9f
# 937                 34           78  e8a6bd97a292436bcebfbe22a16ea0a3
# 947                 82           16  0f328b5466fd3cb271f93b25d6f79b15
# 948                 87           36  36d717a5b3ea8654e86fa8d355ee681f
# 963                 35           15  c72480c8f2b7e472be7234d609000a5f
# 966                 58           13  e518c25072e4d4cdb3a29681e9b23219
# 978                 22           26  1e899bd6e0a23972fa45e678ef5380f5
# 990                122          218  804c7a12dc692de60ad7466bc4047a7b
#
#        user_yelping_since
# 1019  2015-08-02 14:37:56
# 1022  2015-08-31 14:55:38
# 1025  2016-03-21 03:46:05
# 1027  2014-07-17 23:02:28
# 1055  2011-08-21 18:54:41
# 1056  2009-04-08 21:03:08
# 1058  2015-04-15 01:01:08
# 1063  2008-10-09 13:58:09
# 1066  2015-02-20 18:57:59
# 1070  2014-09-02 16:33:11
# 1075  2013-10-12 06:57:38
# 1076  2012-05-04 20:17:26
# 1087  2015-09-09 03:39:21
# 1089  2012-05-28 08:13:56
# 1092  2012-03-16 02:45:21
# 1094  2013-07-28 03:38:40
# 1098  2015-12-27 05:57:51
# 1106  2015-12-08 20:37:24
# 1108  2010-08-02 22:42:22
# 1117  2010-07-13 17:20:02
# 1126  2011-10-04 03:59:44
# 1132  2010-01-28 04:18:06
# 1137  2012-09-07 02:25:44
# 1146  2012-01-03 17:51:34
# 1152  2012-12-20 06:00:40
# 1174  2012-11-27 03:36:03
# 1178  2011-03-30 16:35:52
# 1185  2014-02-12 05:14:24
# 1186  2011-04-20 20:45:51
# 1188  2010-06-29 15:43:08
# ...                   ...
# 822   2012-10-17 06:20:40
# 841   2013-04-10 14:53:15
# 846   2017-03-10 19:18:39
# 853   2009-11-18 03:45:34
# 858   2013-01-11 00:09:50
# 859   2010-02-21 03:22:06
# 863   2011-04-03 18:03:04
# 868   2015-01-03 09:42:25
# 869   2010-10-15 00:05:02
# 870   2014-09-12 19:52:48
# 879   2013-02-16 19:51:19
# 893   2015-10-19 02:21:54
# 898   2014-04-20 08:36:40
# 902   2012-08-02 21:51:20
# 907   2013-07-06 02:41:53
# 909   2016-03-26 23:55:42
# 911   2016-02-03 16:24:13
# 914   2013-08-15 16:07:18
# 916   2012-05-16 16:20:41
# 925   2017-02-11 03:01:50
# 926   2015-10-27 20:53:49
# 928   2012-06-15 18:38:33
# 929   2012-01-09 23:17:20
# 937   2011-05-18 05:19:50
# 947   2015-06-25 03:25:15
# 948   2011-01-04 19:19:30
# 963   2013-10-07 04:58:30
# 966   2010-11-23 00:05:27
# 978   2010-05-14 13:02:44
# 990   2011-08-25 19:51:25
#
# [1472 rows x 21 columns]

# %%
user_df
# Out:
#       user_average_stars  user_compliment_cool  user_compliment_cute  \
# 0                   3.63                     1                     0
# 1                   3.48                     1                     0
# 10                  3.91                    67                     5
# 100                 3.89                     5                     0
# 1000                4.43                    16                     0
# 1001                3.62                    34                     0
# 1002                3.59                     0                     0
# 1003                4.38                    12                     0
# 1004                3.91                     0                     0
# 1005                4.11                    14                     0
# 1006                4.04                     5                     0
# 1007                4.42                     8                     0
# 1008                4.37                     9                     0
# 1009                4.08                    27                     1
# 101                 3.69                     1                     0
# 1010                3.79                     0                     0
# 1011                2.92                     0                     0
# 1012                4.50                    48                     3
# 1013                3.79                    20                     0
# 1014                3.65                     2                     0
# 1015                4.40                     0                     0
# 1016                4.43                     1                     0
# 1017                3.62                     0                     0
# 1018                3.74                   175                     0
# 1019                4.14                     0                     0
# 102                 3.63                     0                     0
# 1020                4.24                     4                     0
# 1021                4.12                   697                    20
# 1022                3.37                     0                     0
# 1023                3.55                    18                     1
# ...                  ...                   ...                   ...
# 972                 3.95                    17                     0
# 973                 3.86                     0                     0
# 974                 4.06                    31                     4
# 975                 3.11                    24                     1
# 976                 3.68                     4                     0
# 977                 3.64                     0                     0
# 978                 3.68                     0                     0
# 979                 4.04                     1                     0
# 98                  3.84                   488                    24
# 980                 3.69                     5                     0
# 981                 4.25                     5                     0
# 982                 4.20                    24                     1
# 983                 3.56                     1                     0
# 984                 3.95                    40                     0
# 985                 3.73                    12                     0
# 986                 3.98                    47                     1
# 987                 3.39                     4                     1
# 988                 3.30                     1                     0
# 989                 3.82                    12                     2
# 99                  4.16                   759                    12
# 990                 3.43                     3                     0
# 991                 4.32                     1                     0
# 992                 4.20                     5                     0
# 993                 3.49                    32                     1
# 994                 3.12                     2                     0
# 995                 3.53                    40                     0
# 996                 3.67                     0                     0
# 997                 4.44                     0                     0
# 998                 4.22                     2                     0
# 999                 2.80                     0                     0
#
#       user_compliment_funny  user_compliment_hot  user_compliment_list  \
# 0                         1                    1                     0
# 1                         1                    0                     0
# 10                       67                   50                     3
# 100                       5                    0                     0
# 1000                     16                    1                     0
# 1001                     34                   14                     0
# 1002                      0                    1                     0
# 1003                     12                    3                     0
# 1004                      0                    0                     0
# 1005                     14                    2                     0
# 1006                      5                    1                     2
# 1007                      8                    6                     0
# 1008                      9                    3                     0
# 1009                     27                   12                     0
# 101                       1                    0                     0
# 1010                      0                    0                     0
# 1011                      0                    0                     0
# 1012                     48                   10                     0
# 1013                     20                    3                     0
# 1014                      2                    0                     0
# 1015                      0                    0                     0
# 1016                      1                    1                     0
# 1017                      0                    0                     0
# 1018                    175                  196                     0
# 1019                      0                    0                     0
# 102                       0                    0                     0
# 1020                      4                    0                     0
# 1021                    697                  532                    14
# 1022                      0                    0                     0
# 1023                     18                   22                     0
# ...                     ...                  ...                   ...
# 972                      17                    2                     0
# 973                       0                    2                     0
# 974                      31                   24                     2
# 975                      24                    9                     0
# 976                       4                    2                     0
# 977                       0                    0                     0
# 978                       0                    0                     0
# 979                       1                    0                     0
# 98                      488                  309                     7
# 980                       5                    2                     0
# 981                       5                    2                     0
# 982                      24                   12                     0
# 983                       1                    0                     1
# 984                      40                   11                     1
# 985                      12                    1                     1
# 986                      47                   14                     0
# 987                       4                    0                     1
# 988                       1                    0                     0
# 989                      12                    0                     3
# 99                      759                  484                     8
# 990                       3                    1                     0
# 991                       1                    8                     0
# 992                       5                    3                     0
# 993                      32                    7                     0
# 994                       2                    0                     0
# 995                      40                   12                     0
# 996                       0                    1                     0
# 997                       0                    0                     0
# 998                       2                    3                     0
# 999                       0                    0                     0
#
#       user_compliment_more  user_compliment_note  user_compliment_photos  \
# 0                        0                     0                       0
# 1                        1                     2                       0
# 10                       5                    28                       8
# 100                      1                     7                      17
# 1000                     7                     9                       6
# 1001                     3                     9                       3
# 1002                     1                     3                       1
# 1003                     1                     3                       1
# 1004                     1                     0                       0
# 1005                     0                     6                       2
# 1006                     0                     2                       1
# 1007                     3                     4                       0
# 1008                     1                     3                       1
# 1009                     4                    18                       6
# 101                      2                     3                       0
# 1010                     0                     1                       0
# 1011                     0                     1                       0
# 1012                     2                     9                       2
# 1013                     3                    11                       6
# 1014                     0                     1                       1
# 1015                     0                     2                       0
# 1016                     0                     0                       0
# 1017                     0                     0                       0
# 1018                    17                    68                      13
# 1019                     0                     0                       0
# 102                      0                     1                       1
# 1020                     1                     0                       0
# 1021                    32                   224                       1
# 1022                     0                     2                       0
# 1023                     2                     9                      30
# ...                    ...                   ...                     ...
# 972                      0                     1                       4
# 973                      0                     0                       1
# 974                      3                    15                       6
# 975                     11                    63                       1
# 976                      1                     9                       0
# 977                      0                     1                       0
# 978                      0                     1                       0
# 979                      1                     1                       0
# 98                      46                   321                      17
# 980                      0                     1                       0
# 981                      1                     3                       0
# 982                      0                     9                      37
# 983                      0                    10                       0
# 984                      5                    19                       5
# 985                      1                     8                       0
# 986                      1                    24                      25
# 987                      2                     4                       0
# 988                      0                     3                       1
# 989                      0                    10                       1
# 99                      28                   253                     236
# 990                      1                     3                       0
# 991                      1                     1                       0
# 992                      0                     6                       2
# 993                      2                    28                      38
# 994                      0                     6                       1
# 995                      1                    14                       5
# 996                      0                     0                       0
# 997                      0                     0                       0
# 998                      3                     2                       0
# 999                      0                     0                       0
#
#       user_compliment_plain         ...           user_compliment_writer  \
# 0                         0         ...                                0
# 1                         2         ...                                0
# 10                       39         ...                               16
# 100                       7         ...                                3
# 1000                      1         ...                               10
# 1001                     22         ...                               17
# 1002                      2         ...                                2
# 1003                      5         ...                                9
# 1004                      2         ...                                2
# 1005                     10         ...                                3
# 1006                     12         ...                                2
# 1007                      9         ...                                3
# 1008                     24         ...                                8
# 1009                     33         ...                               29
# 101                       0         ...                                1
# 1010                      0         ...                                1
# 1011                      1         ...                                0
# 1012                     10         ...                               15
# 1013                      8         ...                                6
# 1014                      1         ...                                5
# 1015                      2         ...                                0
# 1016                      0         ...                                2
# 1017                      1         ...                                0
# 1018                    144         ...                               60
# 1019                      0         ...                                0
# 102                       2         ...                                1
# 1020                      0         ...                                0
# 1021                    425         ...                               92
# 1022                      0         ...                                0
# 1023                     13         ...                                8
# ...                     ...         ...                              ...
# 972                       2         ...                                2
# 973                       1         ...                                1
# 974                      34         ...                               32
# 975                      37         ...                               28
# 976                      10         ...                                1
# 977                       1         ...                                0
# 978                       1         ...                                2
# 979                       4         ...                                1
# 98                      607         ...                              258
# 980                       3         ...                                3
# 981                       4         ...                                2
# 982                      27         ...                                8
# 983                       8         ...                                3
# 984                      35         ...                               22
# 985                       7         ...                                2
# 986                      22         ...                               21
# 987                       3         ...                                1
# 988                       5         ...                                1
# 989                       5         ...                                2
# 99                      420         ...                              389
# 990                       0         ...                                1
# 991                       2         ...                                3
# 992                       6         ...                                3
# 993                      49         ...                               19
# 994                       5         ...                                3
# 995                      18         ...                               17
# 996                       1         ...                                0
# 997                       0         ...                                0
# 998                      15         ...                                3
# 999                       1         ...                                0
#
#       user_cool                          user_elite user_fans  user_funny  \
# 0            16                                             4          22
# 1            22                                             3          16
# 10          411                                            31         507
# 100         215                           2017,2018        21         127
# 1000         98                      2016,2017,2018         6          64
# 1001        152                                2015        10         106
# 1002         72                           2017,2018         4          38
# 1003        145       2013,2014,2015,2016,2017,2018        10         100
# 1004         33                                             2         604
# 1005        120                                            13          49
# 1006         41                                             3          24
# 1007         62                                            11          28
# 1008        132                           2017,2018         5          34
# 1009        712                 2015,2016,2017,2018        45         457
# 101          10                                             1           3
# 1010          5                                             1           3
# 1011          8                                             1          17
# 1012        340                 2015,2016,2017,2018        19         129
# 1013        266                 2015,2016,2017,2018        15          93
# 1014         30                                             5          23
# 1015         35                                             2          16
# 1016         31                                             1          23
# 1017          6                                             1           7
# 1018        587       2012,2013,2014,2015,2016,2017        25         364
# 1019          1                                             0           1
# 102           7                      2016,2017,2018         2           9
# 1020         22                                             5          10
# 1021       2340            2008,2009,2010,2011,2012        43        1755
# 1022         32                                             0          23
# 1023        106                                            19          51
# ...         ...                                 ...       ...         ...
# 972          91                      2016,2017,2018         1          55
# 973           5                                2018         1           3
# 974         612                           2015,2016        41         424
# 975         680  2011,2012,2013,2014,2015,2016,2017        37        1581
# 976          78                           2013,2014         1          62
# 977          13                                             1           8
# 978           8                                             0           4
# 979          52                                2018         2          41
# 98         5463  2012,2013,2014,2015,2016,2017,2018       150        4585
# 980          46                      2016,2017,2018         4          31
# 981         137                 2013,2016,2017,2018        12          90
# 982         156                                            11          94
# 983          55                                             3          44
# 984         409  2012,2013,2014,2015,2016,2017,2018        47         327
# 985         101            2013,2014,2015,2017,2018         8          81
# 986         244                           2014,2015        14         175
# 987          70                                             7         106
# 988          19                                             2          52
# 989          97                           2010,2011         3          75
# 99         7420  2012,2013,2014,2015,2016,2017,2018       167        4396
# 990          59                                             0          63
# 991          44                      2015,2017,2018         1          17
# 992          65                           2017,2018         7          20
# 993         723                      2016,2017,2018        57         222
# 994         146                                            12         206
# 995         174       2011,2012,2013,2014,2015,2016        26         161
# 996          14                                             1          18
# 997           9                                             1           6
# 998          36                      2016,2017,2018         9          21
# 999          10                                             2           6
#
#       user_name user_review_count  user_useful  \
# 0         Jenna                33           48
# 1          Edie                77           71
# 10       Andrew               311          632
# 100      Melody               337          581
# 1000      Brady               137          162
# 1001        Amy               111          266
# 1002  Christine               128          135
# 1003   Benjamin               316          359
# 1004        Yue                55           96
# 1005      Holli               205          345
# 1006       Juan                68          126
# 1007       Jane                45          105
# 1008       Mike               144          231
# 1009      Kelly               802         1467
# 101       Renay                29           46
# 1010      Logan                28           24
# 1011        Rob                56           81
# 1012    Melissa               101          434
# 1013   Lynnette               342          501
# 1014       Joah                64           68
# 1015      Paige               124           68
# 1016       Alex                38           38
# 1017      Lucas                41           56
# 1018    Lindsay               232          878
# 1019      Lynne                35            8
# 102    Christen                76           89
# 1020    Sheldon               135           53
# 1021       Lynn               400         2636
# 1022    Natasha                39           56
# 1023      Sasha                74          196
# ...         ...               ...          ...
# 972       Marco                82          121
# 973     Lindsey                62           32
# 974   Stephanie               307         1103
# 975        Erin               953         3092
# 976     Tatiana                92          142
# 977     Brendan                30           42
# 978     Claudia                22           26
# 979      Nathan               138          188
# 98       Angela              1800         9257
# 980      Lauren               170          100
# 981    Demetria               153          277
# 982         Joy               205          274
# 983         Ray                85          157
# 984        John               529          883
# 985        Mark               308          259
# 986      Takuya                86          329
# 987      Lonely               109          132
# 988       Mihir               158          123
# 989         Dan               106          203
# 99     Isabella               952         8103
# 990          JR               122          218
# 991         Zoe                82          138
# 992     Rebecca               284          166
# 993     Michael               313         1670
# 994     William               197          384
# 995      Channa               474          614
# 996       Sarah                42           33
# 997        Jill                32           36
# 998       Megan                92          147
# 999        Adam                38           26
#
#                                user_id   user_yelping_since
# 0     88422913727e71e88611fdfe3512fa03  2013-02-21 22:29:06
# 1     e9567f1e494c12c4bed031c792a822d0  2009-10-26 01:00:40
# 10    9db7bc1b71703a41fd213acfcf886ee0  2007-07-14 00:50:13
# 100   356638928087978fbdadf2569dcee490  2012-12-13 03:24:06
# 1000  a821031889b7e2a9cf491ee9bf13bd06  2011-03-26 14:05:58
# 1001  c7773a50b020dd4827fc7930c586f8b2  2011-03-10 14:58:02
# 1002  54eea20a91548f256902a2a144e31cee  2014-05-08 08:41:58
# 1003  b21ebde7fa59bfc3212b900399bff289  2010-01-21 18:38:34
# 1004  0684846126a11236d848ff5b395298c4  2011-11-30 06:04:06
# 1005  e56c7bf6b9baaaacfbd101c1e2191123  2011-01-04 15:03:06
# 1006  510bb78d25e160ae0f0697551c0fa363  2013-01-06 05:09:17
# 1007  f059fec71d4a2a3b4eae1dd0be5acbab  2008-06-20 01:32:32
# 1008  d87836496f3dd75fa3bd2d8f004bd91f  2015-12-05 18:15:51
# 1009  ab080aefa50982f6b173e4f7fa23dbe1  2011-04-14 02:29:27
# 101   6207d7777b042d6acf62e324ae4d4dcf  2011-05-14 12:58:59
# 1010  ccd0ac0acbebcd579dfe927e6981779f  2014-11-24 15:25:58
# 1011  9843a2db629e2336a9d551638e8daacf  2009-11-18 00:37:40
# 1012  a94267eb1f992ee1c571818906d2b3f2  2010-07-09 03:21:22
# 1013  147473d597ca46c3c3893e97bffa8764  2012-02-07 15:35:15
# 1014  6d3b2ca63532d0672205b55352070ccf  2012-07-13 18:09:15
# 1015  b3ebcb35547febe37c5ef678b4d021f7  2012-01-18 20:57:22
# 1016  cbece0a93bbf2934ca1714fe91f81ad0  2014-04-02 22:54:24
# 1017  25d347883227826803c50b257ac523e9  2012-07-12 17:58:14
# 1018  49b00f01adc736714f65011e9d2482dd  2011-08-09 21:00:13
# 1019  110362ea155bc27f2faceb6dc76b4e5c  2015-08-02 14:37:56
# 102   dcdc8822c3c3e12e9dd09660ccec16b0  2012-12-07 19:37:20
# 1020  64054107fef29eca1421483cf18ba427  2012-05-28 02:01:03
# 1021  6d1848eaae17e7fd3d33b7c2f106e128  2006-08-30 22:55:36
# 1022  b29e7ca89b94b87372bb7f2f619d0370  2015-08-31 14:55:38
# 1023  3831a04e8acd427f0120bc939dfcbff0  2012-10-01 16:33:55
# ...                                ...                  ...
# 972   6fe718d60801e41da86755242486f362  2012-02-26 22:13:53
# 973   f4cfbfd40f2f3130b38c527127db2d5c  2017-05-08 02:08:37
# 974   6aad7067119bc91d1724d12f860c96ae  2015-01-13 01:27:27
# 975   e47141aa19e5f247024ecc2f08214119  2009-12-27 19:04:09
# 976   b3146274d66babc336b0dee66f4ebd3d  2011-11-05 20:41:00
# 977   302a4eb8199a31d07c37215c2fab11d0  2012-11-02 13:52:52
# 978   1e899bd6e0a23972fa45e678ef5380f5  2010-05-14 13:02:44
# 979   1ea2efcf6e917320877e4ed5e7fb798c  2011-02-02 23:09:17
# 98    ffb9eec7f2fa3e300c69d55b470b9b40  2011-04-11 19:27:40
# 980   44c213a8fb224efff4dc795c24d32d3c  2015-05-29 21:22:58
# 981   fb3969a364fe8feba88560c8b7ece986  2011-08-29 03:40:46
# 982   67326105ca87497c801ddc21c9db7160  2009-06-26 15:32:28
# 983   d09c54d22cc277b404443ebab312e17e  2010-08-13 15:34:59
# 984   3e138b445038b669d243a7aca6f550b7  2010-12-10 20:36:09
# 985   05d9007df0842551cca85ec67c0cf42d  2013-09-01 14:14:25
# 986   aea2c7f9f6eebf23dd45c016a2982fe0  2011-11-06 21:21:06
# 987   3c6022c0b116388ad8dc43b1c86409e0  2011-07-10 06:02:05
# 988   5b38ece29d3533b0212578c07fd31524  2010-07-14 22:00:54
# 989   88541864bb3ce41a32735bf2f194272e  2009-01-11 02:04:49
# 99    853032a59a99ff9a66b8ecf2fdb78fc5  2011-04-16 23:21:01
# 990   804c7a12dc692de60ad7466bc4047a7b  2011-08-25 19:51:25
# 991   870795e89eb4532f6cb89fe33a4dd824  2010-08-12 19:02:19
# 992   eb6c6cc8aa45674c9c33098db1646313  2013-02-12 04:01:19
# 993   f8e3955d9f7efde708ebcd314e75d615  2015-07-29 02:19:04
# 994   7c3b2a2707e8d3a12d7781236be860da  2011-03-12 08:15:33
# 995   ba84156c0fc45692d66ed84ea183cdd4  2009-02-18 14:51:48
# 996   da6839e204c6b2e3b09cf22f79489d8a  2015-03-08 19:02:10
# 997   f1a284d12c10e12149faccfd00eeb045  2011-08-26 00:55:40
# 998   1d970d4d435195fe616c937537829da4  2015-08-02 22:11:54
# 999   c9d7d4f8a37fda3b3ef3c0c8a8a82b54  2013-01-03 02:16:35
#
# [4987 rows x 21 columns]

# %%
item_df
# Out:
#                                         item_address  \
# 0                               30 Eglinton Avenue W
# 1                          10110 Johnston Rd, Ste 15
# 10                             322 Adelaide Street W
# 100                        1005 S Arizona Ave, Ste 9
# 1000                           15233 N Kierland Blvd
# 10000                       210 E Trade St, Ste 104A
# 10001                                  7050 W Ray Rd
# 10002                             6140 Som Center Rd
# 10003                   9711 S Eastern Ave, Ste H-11
# 10004                              8475 S Emerald Dr
# 10005                       13869 W Bell Rd, Ste 107
# 10006                               1101 Central Ave
# 10007                                  7810 W Ann Rd
# 10008                      1116 S Dobson Rd, Ste 123
# 10009                        8665 Concord Mills Blvd
# 1001                    10890 S Eastern Ave, Ste 108
# 10010                 3910 Spring Mountain Rd, Ste 3
# 10011                             180 Baldwin Street
# 10012                            141 Berkeley Street
# 10013                     1150 S Gilbert Rd, Ste 108
# 10014                      4012 W Turney Ave, Ste B2
# 10015                           19110 Old Detroit Rd
# 10016                             531 N Stephanie St
# 10017                             6725 E McDowell Rd
# 10018                              601 N Arizona Ave
# 10019                           4500 W Tropicana Ave
# 1002                              3519 E Baseline Rd
# 10020                        4700 N 12th St, Ste 101
# 10021                        3802 E Indian School Rd
# 10022                                 4210 E Main St
# ...                                              ...
# 9972                  107 Atlantic Avenue, Suite 100
# 9973                       7000 E Mayo Blvd, Bldg 21
# 9974                4545 Spring Mountain Rd, Ste 101
# 9975                                340 Yonge Street
# 9976                               9691 Trailwood Dr
# 9977                                    565 Marks St
# 9978                                  2113 Valley Dr
# 9979                                  1616 W Ruby Dr
# 998                            3950 Las Vegas Blvd S
# 9980                           20 Dundas Street West
# 9981                               9031 W Sahara Ave
# 9982                           3790 Las Vegas Blvd S
# 9983                                 11675 Perry Hwy
# 9984                              3961 S. Gilbert Rd
# 9985                                  3623 Butler St
# 9986                          2510 W Happy Valley Rd
# 9987                          1000 W Warm Springs Rd
# 9988                               1374 Willamson St
# 9989                                 1937 Murray Ave
# 999                                 11607 Euclid Ave
# 9990                            2382 Dundas Street W
# 9991                             9620 N Metro Pkwy W
# 9992                           3799 Las Vegas Blvd S
# 9993                            850 Las Vegas Blvd N
# 9994                       3255 Highway 7 E, Unit 15
# 9995                            5101 N Scottsdale Rd
# 9996                            226 Greenwood Avenue
# 9997                                  3347 N 7th Ave
# 9998                              7000 E. Mayo Blvd.
# 9999   14815 Ballantyne Village Way, Fl 2nd ,Ste 250
#
#                                          item_attributes  \
# 0      {'RestaurantsReservations': 'True', 'GoodForMe...
# 1      {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...
# 10     {'Alcohol': 'u'beer_and_wine'', 'BikeParking':...
# 100    {'RestaurantsPriceRange2': '2', 'ByAppointment...
# 1000   {'RestaurantsAttire': ''dressy'', 'Restaurants...
# 10000  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 10001  {'BikeParking': 'True', 'RestaurantsGoodForGro...
# 10002  {'RestaurantsTableService': 'True', 'WiFi': 'u...
# 10003  {'GoodForKids': 'True', 'BusinessAcceptsCredit...
# 10004  {'BusinessParking': '{'garage': False, 'street...
# 10005  {'RestaurantsPriceRange2': '1', 'BikeParking':...
# 10006  {'RestaurantsAttire': 'u'casual'', 'Restaurant...
# 10007  {'BikeParking': 'True', 'RestaurantsReservatio...
# 10008  {'RestaurantsPriceRange2': '1', 'RestaurantsDe...
# 10009  {'BikeParking': 'False', 'NoiseLevel': 'u'aver...
# 1001   {'RestaurantsTableService': 'True', 'Restauran...
# 10010             {'BusinessAcceptsCreditCards': 'True'}
# 10011  {'RestaurantsAttire': 'u'casual'', 'Restaurant...
# 10012  {'GoodForKids': 'False', 'HasTV': 'False', 'Go...
# 10013  {'RestaurantsAttire': 'u'casual'', 'Restaurant...
# 10014  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 10015  {'GoodForKids': 'False', 'RestaurantsGoodForGr...
# 10016                                               None
# 10017             {'BusinessAcceptsCreditCards': 'True'}
# 10018  {'Ambience': '{'romantic': False, 'intimate': ...
# 10019  {'RestaurantsDelivery': 'False', 'GoodForMeal'...
# 1002   {'RestaurantsAttire': ''casual'', 'NoiseLevel'...
# 10020  {'CoatCheck': 'False', 'DriveThru': 'False', '...
# 10021  {'GoodForKids': 'False', 'ByAppointmentOnly': ...
# 10022  {'BikeParking': 'True', 'Caters': 'True', 'Bus...
# ...                                                  ...
# 9972   {'HasTV': 'True', 'RestaurantsReservations': '...
# 9973   {'BusinessAcceptsBitcoin': 'False', 'BusinessP...
# 9974   {'GoodForMeal': '{'dessert': False, 'latenight...
# 9975   {'Alcohol': 'u'beer_and_wine'', 'BikeParking':...
# 9976   {'RestaurantsDelivery': 'False', 'WiFi': 'u'fr...
# 9977   {'HasTV': 'True', 'BusinessAcceptsBitcoin': 'F...
# 9978   {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 9979   {'RestaurantsPriceRange2': '3', 'ByAppointment...
# 998    {'RestaurantsPriceRange2': '3', 'BusinessAccep...
# 9980   {'NoiseLevel': 'u'average'', 'RestaurantsAttir...
# 9981   {'BusinessParking': '{'valet': False, 'garage'...
# 9982   {'RestaurantsDelivery': 'False', 'BusinessAcce...
# 9983   {'GoodForMeal': '{'dessert': False, 'latenight...
# 9984   {'RestaurantsReservations': 'False', 'Business...
# 9985   {'BusinessAcceptsCreditCards': 'True', 'WiFi':...
# 9986   {'Ambience': '{'romantic': False, 'intimate': ...
# 9987              {'BusinessAcceptsCreditCards': 'True'}
# 9988   {'BikeParking': 'True', 'RestaurantsTakeOut': ...
# 9989   {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 999    {'RestaurantsTakeOut': 'True', 'Ambience': '{'...
# 9990   {'OutdoorSeating': 'False', 'Ambience': '{'rom...
# 9991   {'BusinessParking': '{'garage': False, 'street...
# 9992   {'RestaurantsGoodForGroups': 'True', 'WiFi': '...
# 9993                             {'GoodForKids': 'True'}
# 9994   {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 9995   {'RestaurantsDelivery': 'False', 'RestaurantsA...
# 9996   {'RestaurantsTakeOut': 'True', 'RestaurantsPri...
# 9997   {'BusinessAcceptsBitcoin': 'False', 'WiFi': 'u...
# 9998   {'BusinessParking': '{'garage': False, 'street...
# 9999   {'BusinessAcceptsCreditCards': 'True', 'HasTV'...
#
#                             business_id  \
# 0      23f2cd62b65e6db173f5f40ed9f13a33
# 1      f182f44b05b28d84ad291e4ed2fe5b6a
# 10     109ec8201ca31675ace1d83244c3413b
# 100    20879016f0fbd00b580741888438d5b4
# 1000   79ba35a8e9c56de694874c37689a8a6a
# 10000  160097fe729a2caa29cda43017312a6f
# 10001  4c12a8b12c9e0c2d161848a1c33d80b0
# 10002  0beb5531e8212a8846d80915e85164dc
# 10003  310ff8a69d91390620bb37e451977e3d
# 10004  8bad83206fd5fafdd8d3d6f921460c05
# 10005  4f9a7c989453c2b5e86af34c68ae39b8
# 10006  2906bc18ead1f9dbf1520ef77daf5f26
# 10007  2069f8bc96d3e9527039a3c97852c692
# 10008  4212ff960684ef4dce4fdc8f52830ea0
# 10009  55cbaf42bde953559ddf3a74d03c54f9
# 1001   f1d16465461d43967611abe8e746ba3a
# 10010  2603451aa42274de7e583014c1cc756c
# 10011  8eef9fbb751d3b01da1d67ead276205e
# 10012  00f3048af106561c1c34164a75613261
# 10013  f6e8f86e7d24792d43bdde0b302462fb
# 10014  a8dabce1804799cef8ccc2540e1d9c97
# 10015  e186315ab226005aa8107fa7d77a007d
# 10016  01d2741ba0b8fc6537a46db2c4dfe79a
# 10017  82362d4f67f7887855a969e8f17c8242
# 10018  12fa348bf5ac73d963ab350bb4ed930e
# 10019  8da71ff9297c803ea587e09de06b8cc4
# 1002   40898629f9594f11529eeff74b9d42fe
# 10020  c6fc9c9992f25b87ce25ad1c0d1f7283
# 10021  a7901921f7c5fd581092c2d2a885aef5
# 10022  c25c9d2d799867a084eea8a526c8ddde
# ...                                 ...
# 9972   68c206f8ee14991111290525da3f6376
# 9973   add6d42b58d12d206e17a1311d1a61c2
# 9974   97614b3f2755c98fe10f282700e92d3b
# 9975   7cb704d60481ab71ef631320cee6502f
# 9976   1cec1d7b71ca2ffbb030948db18d0301
# 9977   b01acb835ba8ca989d0552536353c76a
# 9978   3757ace02f6a6329ebc4318e8ce73993
# 9979   8a7405cd5a6d6e411f37eba2cb9ed809
# 998    817dd22fc69a6783b068157f73b84e57
# 9980   2b43df510f9ce2f2cab3796a16dbb6e9
# 9981   7002a8b4cb1594ca4a6e7f31d1375c14
# 9982   877e70014cd2992e821d76fa5a6f791a
# 9983   62b6cd2ea17d89085d2565c2343ffc35
# 9984   f0647b4c737e307515e7d4518cba03a2
# 9985   a2a6ea59c31297605149f3978051a004
# 9986   060f5d6b4b8a90518520ad5d7643abfe
# 9987   b91b2c51f5a89bec9ddd5cc1acbd99be
# 9988   aba53c723b77b63993c897a71133f323
# 9989   b966bdc11fa97060e4e568a3b95fce72
# 999    a18a53546fd2391a9d07c79b35a0ec4b
# 9990   b389d818b33cb3fd6e9496900f1a974f
# 9991   c536099462960d390a88f4d9d9401f80
# 9992   e1612862b8a811f454068e5b9c5d012e
# 9993   6c2584807bb2b14db9a1a05c8c1c648f
# 9994   b8b9ba70d61228e20abcdff616161f4a
# 9995   5f5ee871bc5d8ffb82d5f6c504be79d5
# 9996   b114540ca59a4e2695010a00c5e6743d
# 9997   9dbf422e6de5bf89c876207d9381191c
# 9998   b9c8954809abfdbc310f2c894917a9ab
# 9999   dbba47328ae3fd2bb286ebae9f932398
#
#                                          item_categories    item_city  \
# 0      Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga
# 1                      Sushi Bars, Restaurants, Japanese    Charlotte
# 10                         Soup, Restaurants, Sandwiches      Toronto
# 100    Eyelash Service, Hair Removal, Beauty & Spas, ...     Chandler
# 1000   American (Traditional), Steakhouses, Restauran...   Scottsdale
# 10000                               Mexican, Restaurants    Charlotte
# 10001                    Burgers, Restaurants, Fast Food     Chandler
# 10002                               Mexican, Restaurants        Solon
# 10003  Hair Salons, Barbers, Beauty & Spas, Hair Styl...    Las Vegas
# 10004  Gun/Rifle Ranges, Active Life, Shopping, Guns ...        Tempe
# 10005                    Restaurants, Fast Food, Mexican     Surprise
# 10006  Nightlife, Beer, Wine & Spirits, Burgers, Bars...    Charlotte
# 10007           Salad, Pizza, Restaurants, Chicken Wings    Las Vegas
# 10008                               Restaurants, Chinese         Mesa
# 10009  Fast Food, Salad, Restaurants, American (Tradi...      Concord
# 1001   Food, Sandwiches, Restaurants, Beer, Wine & Sp...    Henderson
# 10010  Auto Repair, Automotive, Oil Change Stations, ...    Las Vegas
# 10011             Cafes, Restaurants, Breakfast & Brunch      Toronto
# 10012               Mexican, Restaurants, Latin American      Toronto
# 10013  Burgers, Ice Cream & Frozen Yogurt, Cheesestea...      Gilbert
# 10014  Local Services, Professional Services, Packing...      Phoenix
# 10015  Mediterranean, Bars, Nightlife, Wine Bars, Sal...  Rocky River
# 10016  Pet Stores, Pet Groomers, Pet Services, Pets, ...    Henderson
# 10017  Car Dealers, Auto Repair, Used Car Dealers, Au...   Scottsdale
# 10018  Mexican, Breakfast & Brunch, Restaurants, Cate...     Chandler
# 10019  Nightlife, Cocktail Bars, Steakhouses, America...    Las Vegas
# 1002                                Mexican, Restaurants      Gilbert
# 10020  Tapas Bars, Breakfast & Brunch, Nightlife, Ame...      Phoenix
# 10021  Fitness & Instruction, Yoga, Active Life, Food...      Phoenix
# 10022  Custom Cakes, Bakeries, Restaurants, Wedding P...         Mesa
# ...                                                  ...          ...
# 9972   Pubs, Gastropubs, Brasseries, Nightlife, Beer,...      Toronto
# 9973         Salad, Food, Desserts, Mexican, Restaurants      Phoenix
# 9974   Restaurants, Fast Food, Food, Poke, Japanese, ...    Las Vegas
# 9975                                   Thai, Restaurants      Toronto
# 9976   Sandwiches, Food, Juice Bars & Smoothies, Rest...    Las Vegas
# 9977   Mediterranean, Restaurants, Greek, Middle Eastern    Henderson
# 9978                   Handyman, Plumbing, Home Services    Las Vegas
# 9979   Beauty & Spas, Hair Salons, Gyms, Sports Clubs...        Tempe
# 998    Event Planning & Services, Hotels & Travel, Ho...    Las Vegas
# 9980        American (Traditional), Restaurants, Seafood      Toronto
# 9981                           Bagels, Food, Restaurants    Las Vegas
# 9982                            Restaurants, Steakhouses    Las Vegas
# 9983                     Fast Food, Mexican, Restaurants      Wexford
# 9984   Barbeque, Restaurants, Steakhouses, American (...      Gilbert
# 9985                                  Food, Coffee & Tea   Pittsburgh
# 9986   American (New), Soup, Restaurants, Sandwiches,...      Phoenix
# 9987   Car Buyers, Used Car Dealers, Car Dealers, Aut...    Henderson
# 9988           Food, Restaurants, Nightlife, Pizza, Bars      Madison
# 9989   Tea Rooms, Restaurants, Food, Coffee & Tea, Ve...   Pittsburgh
# 999    Beer, Wine & Spirits, Wine Bars, Nightlife, Pa...    Cleveland
# 9990             Japanese, Korean, Barbeque, Restaurants  Mississauga
# 9991    Diners, Breakfast & Brunch, Restaurants, Mexican      Phoenix
# 9992                            Lounges, Nightlife, Bars    Las Vegas
# 9993             Stadiums & Arenas, Arts & Entertainment    Las Vegas
# 9994                     Taiwanese, Chinese, Restaurants      Markham
# 9995   Mexican, Restaurants, Seafood, Breakfast & Brunch   Scottsdale
# 9996   Breakfast & Brunch, Egyptian, Middle Eastern, ...      Toronto
# 9997                                Restaurants, Mexican      Phoenix
# 9998   Burgers, Restaurants, American (Traditional), ...      Phoenix
# 9999               Sushi Bars, Restaurants, Asian Fusion    Charlotte
#
#                                               item_hours  item_is_open  \
# 0      {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...             1
# 1      {'Monday': '17:30-21:30', 'Wednesday': '17:30-...             1
# 10     {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...             1
# 100    {'Monday': '9:0-19:0', 'Tuesday': '9:0-19:0', ...             1
# 1000   {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...             1
# 10000  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...             1
# 10001  {'Monday': '10:30-1:0', 'Tuesday': '10:30-1:0'...             1
# 10002  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...             0
# 10003  {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...             1
# 10004  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...             1
# 10005  {'Monday': '10:45-22:0', 'Tuesday': '10:45-22:...             1
# 10006  {'Monday': '16:0-22:0', 'Tuesday': '11:0-22:0'...             1
# 10007  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...             1
# 10008  {'Monday': '10:30-21:0', 'Tuesday': '10:30-21:...             1
# 10009  {'Monday': '0:0-0:0', 'Tuesday': '10:30-21:0',...             1
# 1001                                                None             0
# 10010  {'Monday': '9:30-18:0', 'Tuesday': '9:30-18:0'...             1
# 10011                                               None             1
# 10012  {'Monday': '12:0-22:0', 'Tuesday': '12:0-22:0'...             1
# 10013  {'Monday': '10:30-21:0', 'Tuesday': '10:30-21:...             0
# 10014  {'Monday': '0:0-0:0', 'Tuesday': '6:30-18:0', ...             1
# 10015  {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:30',...             1
# 10016  {'Monday': '7:0-21:0', 'Tuesday': '7:0-21:0', ...             1
# 10017  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...             1
# 10018  {'Monday': '8:0-21:0', 'Tuesday': '8:0-21:0', ...             1
# 10019  {'Monday': '16:0-22:0', 'Tuesday': '16:0-22:0'...             1
# 1002                                                None             1
# 10020  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...             1
# 10021  {'Monday': '6:0-20:30', 'Tuesday': '6:0-20:30'...             1
# 10022  {'Monday': '7:0-17:0', 'Tuesday': '7:0-17:0', ...             1
# ...                                                  ...           ...
# 9972   {'Monday': '11:0-2:0', 'Tuesday': '11:0-2:0', ...             1
# 9973   {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...             1
# 9974   {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...             0
# 9975   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...             1
# 9976   {'Monday': '6:0-20:0', 'Tuesday': '6:0-20:0', ...             1
# 9977   {'Monday': '0:0-0:0', 'Tuesday': '11:0-20:0', ...             1
# 9978   {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...             1
# 9979   {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...             1
# 998                                                 None             0
# 9980   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...             1
# 9981                                                None             1
# 9982   {'Monday': '16:0-23:0', 'Tuesday': '16:0-23:0'...             1
# 9983   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...             1
# 9984   {'Monday': '15:30-21:30', 'Tuesday': '15:30-21...             1
# 9985   {'Monday': '7:0-21:0', 'Tuesday': '7:0-21:0', ...             1
# 9986   {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...             1
# 9987   {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...             1
# 9988   {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...             1
# 9989   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...             1
# 999    {'Tuesday': '10:0-0:0', 'Wednesday': '10:0-0:0...             0
# 9990   {'Monday': '11:0-22:30', 'Tuesday': '11:0-22:3...             1
# 9991   {'Monday': '8:0-21:0', 'Tuesday': '8:0-21:0', ...             1
# 9992   {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...             1
# 9993                                                None             1
# 9994   {'Monday': '0:0-0:0', 'Wednesday': '11:30-16:0...             1
# 9995   {'Monday': '7:0-22:0', 'Tuesday': '7:0-22:0', ...             0
# 9996   {'Monday': '8:0-19:0', 'Tuesday': '8:0-19:0', ...             1
# 9997   {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...             1
# 9998   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...             1
# 9999   {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...             1
#
#        item_latitude  item_longitude                              item_name  \
# 0          43.605499      -79.652289             Emerald Chinese Restaurant
# 1          35.092564      -80.859132            Musashi Japanese Restaurant
# 10         43.647585      -79.392032                             Ravi Soups
# 100        33.290984     -111.841126                     Mirage Nails & Spa
# 1000       33.625352     -111.926167                Morton's The Steakhouse
# 10000      35.225882      -80.841993         Vida Mexican Kitchen y Cantina
# 10001      33.320455     -111.964159                        In-N-Out Burger
# 10002      41.392161      -81.438536                            Pacos Tacos
# 10003      36.012499     -115.119687                       Cool Cuts 4 Kids
# 10004      33.338890     -111.968500                            C2 Tactical
# 10005      33.638211     -112.359095                 Chipotle Mexican Grill
# 10006      35.221748      -80.819321                Kickstand Burgers & Bar
# 10007      36.264032     -115.266209                        Above the Crust
# 10008      33.394395     -111.875888                  Best Hong Kong Dining
# 10009      35.374317      -80.727584                          PDQ - Concord
# 1001       35.995645     -115.099883                           Burger Joint
# 10010      36.126516     -115.192007                         Samurai Motors
# 10011      43.654826      -79.400768                               Our Spot
# 10012      43.654927      -79.365475                       Cocina Economica
# 10013      33.328977     -111.790797          Mike's Burgers & Cheesesteaks
# 10014      33.501878     -112.144978              Creative Moving & Packing
# 10015      41.483033      -81.834288              Tartine Bistro & Wine Bar
# 10016      36.058395     -115.048256                               PetSmart
# 10017      33.464993     -111.935388                Certified Benz & Beemer
# 10018      33.313554     -111.841224                 Moreno's Mexican Grill
# 10019      36.102563     -115.201190                          Alder & Birch
# 1002       33.378042     -111.755457                   Nando's Mexican Cafe
# 10020      33.505794     -112.056933                       Original Gravity
# 10021      33.495453     -112.000055           The Madison Improvement Club
# 10022      33.416204     -111.740273                  Sassy's Cafe & Bakery
# ...              ...             ...                                    ...
# 9972       43.639408      -79.420820           The Craft Brasserie & Grille
# 9973       33.658418     -111.930540    Carlos O'Brien's Mexican Restaurant
# 9974       36.125636     -115.202487               California Sushi Burrito
# 9975       43.657648      -79.381728                  Salad King Restaurant
# 9976       36.190941     -115.307202                       Rachel's Kitchen
# 9977       36.062289     -115.036933                           Greek Bistro
# 9978       36.197590     -115.198110            Arturo The Handyman Repairs
# 9979       33.340286     -111.964733                      Life Time Fitness
# 998        36.087535     -115.174742              The Hotel At Mandalay Bay
# 9980       43.656363      -79.383616                            Red Lobster
# 9981       36.143822     -115.294084                          Einstein Bros
# 9982       36.102645     -115.174534                 Gallagher's Steakhouse
# 9983       40.626706      -80.055544                   Patron Mexican Grill
# 9984       33.278223     -111.789141                        Texas Roadhouse
# 9985       40.466083      -79.965091                        Espresso A Mano
# 9986       33.715096     -112.113699                             Café Zupas
# 9987       36.057992     -115.030393                                 CarMax
# 9988       43.085616      -89.361521                      Grampa's Pizzeria
# 9989       40.434965      -79.922808                              Dobra Tea
# 999        41.510902      -81.603330                    Coquette Patisserie
# 9990       43.529373      -79.673477  Miga Korean & Japanese BBQ Restaurant
# 9991       33.574124     -112.125615                              Mi Pueblo
# 9992       36.102165     -115.169804                           Whiskey Down
# 9993       36.179894     -115.130281                          Cashman Field
# 9994       43.848355      -79.349080             Mei Nung Beef Noodle House
# 9995       33.510917     -111.924698   Papi Chulo's Mexican Grill & Cantina
# 9996       43.671680      -79.328577                                 Maha's
# 9997       33.487475     -112.083034                               Mi Patio
# 9998       33.655913     -111.928109              Red Robin Gourmet Burgers
# 9999       35.053566      -80.851867                      Jade Asian Fusion
#
#       item_postal_code  item_review_count  item_stars item_state  \
# 0              L5R 3E7                128         2.5         ON
# 1                28210                170         4.0         NC
# 10             M5V 1R1                332         4.5         ON
# 100              85286                121         3.5         AZ
# 1000             85254                173         3.0         AZ
# 10000            28202                393         3.5         NC
# 10001            85226                164         4.0         AZ
# 10002            44139                135         2.5         OH
# 10003            89123                168         4.0         NV
# 10004            85284                245         4.0         AZ
# 10005            85374                130         2.5         AZ
# 10006            28204                299         4.0         NC
# 10007            89149                267         4.0         NV
# 10008            85202                131         3.5         AZ
# 10009            28027                147         4.0         NC
# 1001             89052                185         4.5         NV
# 10010            89102                121         4.5         NV
# 10011          M5T 1L8                122         4.0         ON
# 10012          M5A 2X1                161         4.0         ON
# 10013            85296                226         3.5         AZ
# 10014            85019                192         4.5         AZ
# 10015            44116                127         4.0         OH
# 10016            89014                120         3.0         NV
# 10017            85257                168         3.5         AZ
# 10018            85225                154         4.0         AZ
# 10019            89103                146         4.5         NV
# 1002             85234                352         3.5         AZ
# 10020            85014                151         4.5         AZ
# 10021            85018                116         4.5         AZ
# 10022            85205                122         4.5         AZ
# ...                ...                ...         ...        ...
# 9972           M6K 1Y2                128         3.5         ON
# 9973             85054                130         3.5         AZ
# 9974             89102                137         4.5         NV
# 9975           M5B 1R8                876         3.5         ON
# 9976             89134                266         3.5         NV
# 9977             89014                361         4.5         NV
# 9978             89108                224         5.0         NV
# 9979             85284                211         3.5         AZ
# 998              89119                826         4.0         NV
# 9980           M5G 2C2                132         3.0         ON
# 9981             89117                130         2.0         NV
# 9982             89109               1148         4.0         NV
# 9983             15090                156         3.5         PA
# 9984             85296                218         3.5         AZ
# 9985             15201                314         4.5         PA
# 9986             85085                135         3.0         AZ
# 9987             89014                238         3.0         NV
# 9988             53703                240         4.5         WI
# 9989             15217                167         4.5         PA
# 999              44106                136         4.0         OH
# 9990           L5K 1R7                172         4.0         ON
# 9991             85051                173         4.0         AZ
# 9992             89109                121         3.5         NV
# 9993             89101                117         3.5         NV
# 9994           L3R 3P3                242         4.0         ON
# 9995             85250                198         3.0         AZ
# 9996           M4L 2R2                376         4.0         ON
# 9997             85013                600         4.0         AZ
# 9998             85054                141         3.0         AZ
# 9999             28277                152         3.5         NC
#
#        item_city_idx  item_postal_code_idx  item_state_idx
# 0                  1                     1               1
# 1                  2                     2               2
# 10                 3                     3               1
# 100                4                     4               3
# 1000               5                     5               3
# 10000              2                     6               2
# 10001              4                     7               3
# 10002              6                     8               4
# 10003              7                     9               5
# 10004              8                    10               3
# 10005              9                    11               3
# 10006              2                    12               2
# 10007              7                    13               5
# 10008             10                    14               3
# 10009             11                    15               2
# 1001              12                    16               5
# 10010              7                    17               5
# 10011              3                    18               1
# 10012              3                    19               1
# 10013             13                    20               3
# 10014             14                    21               3
# 10015             15                    22               4
# 10016             12                    23               5
# 10017              5                    24               3
# 10018              4                    25               3
# 10019              7                    26               5
# 1002              13                    27               3
# 10020             14                    28               3
# 10021             14                    29               3
# 10022             10                    30               3
# ...              ...                   ...             ...
# 9972               3                  1434               1
# 9973              14                   122               3
# 9974               7                    17               5
# 9975               3                  1227               1
# 9976               7                    95               5
# 9977              12                    23               5
# 9978               7                   243               5
# 9979               8                    10               3
# 998                7                    88               5
# 9980               3                   372               1
# 9981               7                    48               5
# 9982               7                    37               5
# 9983              23                    56               7
# 9984              13                    20               3
# 9985              29                    83               7
# 9986              14                    67               3
# 9987              12                    23               5
# 9988              25                    62               8
# 9989              29                   275               7
# 999               19                   296               4
# 9990               1                  1252               1
# 9991              14                   379               3
# 9992               7                    37               5
# 9993               7                   118               5
# 9994              34                   791               1
# 9995               5                   247               3
# 9996               3                  1435               1
# 9997              14                    34               3
# 9998              14                   122               3
# 9999               2                   154               2
#
# [10914 rows x 17 columns]

# %%
from collections import Counter
from itertools import combinations
from math import sqrt
import random
from keras.layers import Concatenate, Dense, Dot, Dropout, Embedding, Input, Reshape
from keras.models import Model
from keras.callbacks import Callback, ModelCheckpoint
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import tensorflow


STUDENT_ID = '23846183'

random.seed(2019)
np.random.seed(2019)
tensorflow.set_random_seed(2019)


# Function to calculate RMSE
def rmse(pred, actual):
    # Ignore nonzero terms.
    pred = pred[actual.nonzero()].flatten()
    actual = actual[actual.nonzero()].flatten()
    return sqrt(mean_squared_error(pred, actual))


def build_deepwide_model(len_continuous, deep_vocab_lens, len_wide, embed_size):
    input_list = []
    continuous_input = Input(shape=(len_continuous,), dtype='float32', name='continuous_input')
    input_list.append(continuous_input)

    emb_list = []
    for vocab_size in deep_vocab_lens:
        _input = Input(shape=(1,), dtype='int32')
        input_list.append(_input)
        _emb = Embedding(output_dim=embed_size, input_dim=vocab_size, input_length=1)(_input)
        _emb = Reshape((embed_size,))(_emb)
        emb_list.append(_emb)

    deep_input = Concatenate()(emb_list + [continuous_input])
    
    dense_1 = Dense(100, activation='relu')(deep_input)
    dense_1_dp = Dropout(0.01)(dense_1)
    dense_2 = Dense(64, activation='relu')(dense_1_dp)
    dense_2_dp = Dropout(0.01)(dense_2)
    dense_3 = Dense(64, activation='relu')(dense_2_dp)
    dense_3_dp = Dropout(0.01)(dense_3)

    wide_input = Input(shape=(len_wide,), dtype='float32')
    input_list.append(wide_input)
    
    fc_input = Concatenate()([dense_3_dp, wide_input])
    # out_fc = Dense(256, activation='relu')(fc_input)
    model_output = Dense(1)(fc_input)
    model = Model(inputs=input_list,
                  outputs=model_output)
    return model


def get_continuous_features(df, continuous_columns):
    continuous_features = df[continuous_columns].values
    return continuous_features


def get_top_k_p_combinations(df, comb_p, topk, output_freq=False):
    def get_category_combinations(categories_str, comb_p=2):
        categories = categories_str.split(', ')
        return list(combinations(categories, comb_p))
    all_categories_p_combos = df["item_categories"].apply(
        lambda x: get_category_combinations(x, comb_p)).values.tolist()
    all_categories_p_combos = [tuple(t) for item in all_categories_p_combos for t in item]
    tmp = dict(Counter(all_categories_p_combos))
    sorted_categories_combinations = list(sorted(tmp.items(), key=lambda x: x[1], reverse=True))
    if output_freq:
        return sorted_categories_combinations[:topk]
    else:
        return [t[0] for t in sorted_categories_combinations[:topk]]


def get_wide_features(df):
    def categories_to_binary_output(categories):
        binary_output = [0 for _ in range(len(selected_categories_to_idx))]
        for category in categories.split(', '):
            if category in selected_categories_to_idx:
                binary_output[selected_categories_to_idx[category]] = 1
            else:
                binary_output[0] = 1
        return binary_output
    def categories_cross_transformation(categories):
        current_category_set = set(categories.split(', '))
        corss_transform_output = [0 for _ in range(len(top_combinations))]
        for k, comb_k in enumerate(top_combinations):
            if len(current_category_set & comb_k) == len(comb_k):
                corss_transform_output[k] = 1
            else:
                corss_transform_output[k] = 0
        return corss_transform_output

    category_binary_features = np.array(df.item_categories.apply(
        lambda x: categories_to_binary_output(x)).values.tolist())
    category_corss_transform_features = np.array(df.item_categories.apply(
        lambda x: categories_cross_transformation(x)).values.tolist())
    return np.concatenate((category_binary_features, category_corss_transform_features), axis=1)

# %%
tr_df = pd.read_csv("data/train.csv")
val_df = pd.read_csv("data/valid.csv")
te_df = pd.read_csv("data/test.csv")

tr_ratings = tr_df.stars.values
val_ratings = val_df.stars.values

user_df = pd.read_json("data/user.json")
item_df = pd.read_json("data/business.json")
user_df = user_df.rename(index=str, columns={t: 'user_' + t for t in user_df.columns if t != 'user_id'})
item_df = item_df.rename(index=str, columns={t: 'item_' + t for t in item_df.columns if t != 'business_id'})

tr_df["index"] = tr_df.index
val_df["index"]  = val_df.index
te_df["index"] = te_df.index
tr_df = pd.merge(pd.merge(tr_df, user_df, on='user_id'), item_df, on='business_id').sort_values(by=['index']).reset_index(drop=True)
val_df = pd.merge(pd.merge(val_df, user_df, on='user_id'), item_df, on='business_id').sort_values(by=['index']).reset_index(drop=True)
te_df = pd.merge(pd.merge(te_df, user_df, on='user_id'), item_df, on='business_id').sort_values(by=['index']).reset_index(drop=True)

# Continuous features
print("Prepare continuous features...")
continuous_columns = ["user_average_stars", "user_cool", "user_fans", 
                      "user_review_count", "user_useful", "user_funny",
                      "item_is_open", "item_latitude", "item_longitude", 
                      "item_review_count", "item_stars"]
tr_continuous_features = get_continuous_features(tr_df, continuous_columns)
val_continuous_features = get_continuous_features(val_df, continuous_columns)
te_continuous_features = get_continuous_features(te_df, continuous_columns)
scaler = StandardScaler().fit(tr_continuous_features)
tr_continuous_features = scaler.transform(tr_continuous_features)
val_continuous_features = scaler.transform(val_continuous_features)
te_continuous_features = scaler.transform(te_continuous_features)

# Deep features
print("Prepare deep features...")
# item_deep_columns = ["item_city", "item_postal_code", "item_state"]
item_deep_columns = ["item_city", "item_postal_code", "item_state"]
item_deep_vocab_lens = []
for col_name in item_deep_columns:
    tmp = item_df[col_name].unique()
    vocab = dict(zip(tmp, range(1, len(tmp) + 1)))
    item_deep_vocab_lens.append(len(vocab) + 1)
    item_df[col_name + "_idx"] = item_df[col_name].apply(lambda x: vocab[x] if x in vocab else 0)
item_deep_idx_columns = [t + "_idx" for t in item_deep_columns]
item_to_deep_features = dict(zip(item_df.business_id.values, item_df[item_deep_idx_columns].values.tolist()))
tr_deep_features = np.array(tr_df.business_id.apply(lambda x: item_to_deep_features[x]).values.tolist())
val_deep_features = np.array(val_df.business_id.apply(lambda x: item_to_deep_features[x]).values.tolist())
te_deep_features = np.array(te_df.business_id.apply(lambda x: item_to_deep_features[x]).values.tolist())

# Wide (Category) features
print("Prepare wide features...")
#   Prepare binary encoding for each selected categories
all_categories = [category for category_list in item_df.item_categories.values for category in category_list.split(", ")]
category_sorted = sorted(Counter(all_categories).items(), key=lambda x: x[1], reverse=True)
selected_categories = [t[0] for t in category_sorted[:00]]
selected_categories_to_idx = dict(zip(selected_categories, range(1, len(selected_categories) + 1)))
selected_categories_to_idx['unk'] = 0
idx_to_selected_categories = {val: key for key, val in selected_categories_to_idx.items()}
#   Prepare Cross transformation for each categories
top_combinations = []
top_combinations += get_top_k_p_combinations(tr_df, 2, 200, output_freq=False)
top_combinations += get_top_k_p_combinations(tr_df, 3, 80, output_freq=False)
top_combinations += get_top_k_p_combinations(tr_df, 4, 40, output_freq=False)
top_combinations += get_top_k_p_combinations(tr_df, 5, 20, output_freq=False)

top_combinations = [set(t) for t in top_combinations]

tr_wide_features = get_wide_features(tr_df)
val_wide_features = get_wide_features(val_df)
te_wide_features = get_wide_features(te_df)

# Build input
tr_features = []
tr_features.append(tr_continuous_features.tolist())
tr_features += [tr_deep_features[:,i].tolist() for i in range(len(tr_deep_features[0]))]
tr_features.append(tr_wide_features.tolist())
val_features = []
val_features.append(val_continuous_features.tolist())
val_features += [val_deep_features[:,i].tolist() for i in range(len(val_deep_features[0]))]
val_features.append(val_wide_features.tolist())
te_features = []
te_features.append(te_continuous_features.tolist())
te_features += [te_deep_features[:,i].tolist() for i in range(len(te_deep_features[0]))]
te_features.append(te_wide_features.tolist())
# Out:
# Prepare continuous features...
# Prepare deep features...
# Prepare wide features...

# %%
# Model training
print(len(tr_continuous_features[0]))
print(tr_continuous_features[0])
print(item_deep_vocab_lens)
print(len(tr_wide_features[0]))
# Out:
# 11
# [-1.45650354 -0.13715845  0.37009944  1.56067061  0.10171985 -0.0509457
#   0.33516366 -0.13118059 -0.66911938  2.89952001  0.32439266]
# [187, 1436, 14]
# 841

# %%
deepwide_model = build_deepwide_model(
    len(tr_continuous_features[0]),
    item_deep_vocab_lens,  
    len(tr_wide_features[0]), 
    embed_size=110)
deepwide_model.compile(optimizer='adagrad', loss='mse')
history = deepwide_model.fit(
    tr_features, 
    tr_ratings,
    batch_size=1024,
    epochs=5, verbose=1, callbacks=[ModelCheckpoint('model.h5')])
# ,validation_data=(val_features,val_ratings)
# Make Prediction
y_pred = deepwide_model.predict(tr_features)                                        
print("TRAIN RMSE: ", rmse(y_pred, tr_ratings))
y_pred = deepwide_model.predict(val_features)
print("VALID RMSE: ", rmse(y_pred, val_ratings))
#     y_pred = deepwide_model.predict(te_features)
#     res_df = pd.DataFrame()
#     res_df['pred'] = y_pred[:, 0]
#     res_df.to_csv("{}.csv".format(STUDENT_ID), index=False)
#     print("Writing test predictions to file done.")
# Out:
# Epoch 1/5
# 100000/100000 [==============================] - 7s 70us/step - loss: 1.5903
# Epoch 2/5
# 100000/100000 [==============================] - 2s 22us/step - loss: 1.0893
# Epoch 3/5
# 100000/100000 [==============================] - 2s 22us/step - loss: 1.0733
# Epoch 4/5
# 100000/100000 [==============================] - 2s 22us/step - loss: 1.0675
# Epoch 5/5
# 100000/100000 [==============================] - 2s 22us/step - loss: 1.0598
# TRAIN RMSE:  1.0221280698609931
# VALID RMSE:  1.040743941618628
